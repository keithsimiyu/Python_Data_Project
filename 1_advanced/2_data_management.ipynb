# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\KEITH\Downloads\data_jobs.csv")

# %%
df["job_posted_date"]= pd.to_datetime(df["job_posted_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df.sample(5,random_state=44)
# Out:
#               job_title_short                             job_title  \
# 653466         Data Scientist  CRM & Loyalty Data Scientist (m/w/x)
# 630858           Data Analyst               Manager, Data Analytics
# 546244           Data Analyst                          Data Analyst
# 435327  Senior Data Scientist                 Senior Data Scientist
# 153958           Data Analyst       Analyst - Business Data Analyst
#
#                    job_location                         job_via  \
# 653466  Wiener Neudorf, Austria  via SmartRecruiters Job Search
# 630858              Chicago, IL                    via LinkedIn
# 546244            Baltimore, MD            via Jobs Trabajo.org
# 435327            Santa Ana, CA                       via BeBee
# 153958           Washington, DC            via Jobs Trabajo.org
#
#        job_schedule_type  job_work_from_home            search_location  \
# 653466         Full-time               False                    Austria
# 630858         Full-time               False    Illinois, United States
# 546244         Full-time               False    New York, United States
# 435327         Full-time               False  California, United States
# 153958         Full-time               False    New York, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 653466 2023-06-19 10:48:31                  False                 False
# 630858 2023-09-27 12:01:42                  False                  True
# 546244 2023-07-28 19:00:23                  False                 False
# 435327 2023-03-09 16:05:54                  False                  True
# 153958 2023-08-25 08:00:48                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 653466        Austria         NaN              NaN              NaN
# 630858  United States         NaN              NaN              NaN
# 546244  United States         NaN              NaN              NaN
# 435327  United States         NaN              NaN              NaN
# 153958  United States         NaN              NaN              NaN
#
#                                              company_name  \
# 653466  REWE International Dienstleistungsgesellschaft...
# 630858                                                RWE
# 546244              University of Maryland Medical System
# 435327                                     First American
# 153958                                           Quadrant
#
#                                                job_skills  \
# 653466  ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 630858  ['sql', 'python', 'sql server', 'visio', 'tabl...
# 546244                                             ['go']
# 435327      ['python', 'sql', 'aws', 'pyspark', 'docker']
# 153958                                                NaN
#
#                                           job_type_skills
# 653466  {'analyst_tools': ['tableau'], 'libraries': ['...
# 630858  {'analyst_tools': ['visio', 'tableau'], 'datab...
# 546244                            {'programming': ['go']}
# 435327  {'cloud': ['aws'], 'libraries': ['pyspark'], '...
# 153958                                                NaN
